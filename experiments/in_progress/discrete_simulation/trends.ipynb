# %%
import pandas as pd

def analyze_csv(file_path):
    # Read the CSV file, skipping bad lines and converting non-numeric data to NaN
    df = pd.read_csv(file_path)
    
    # Drop rows where any essential column has NaN
    df.dropna(subset=['Completed Rides', 'Total Distance', 'Total USD', 'Current Time', 'Number of Drivers', 'Number of Ride Requests', 'Number of Riders'], inplace=True)
    
    # Convert columns to numeric, forcing errors to NaN
    df['Completed Rides'] = pd.to_numeric(df['Completed Rides'], errors='coerce')
    df['Total Distance'] = pd.to_numeric(df['Total Distance'], errors='coerce')
    df['Total USD'] = pd.to_numeric(df['Total USD'], errors='coerce')
    df['Current Time'] = pd.to_numeric(df['Current Time'], errors='coerce')
    df['Number of Drivers'] = pd.to_numeric(df['Number of Drivers'], errors='coerce')
    df['Number of Ride Requests'] = pd.to_numeric(df['Number of Ride Requests'], errors='coerce')
    df['Number of Riders'] = pd.to_numeric(df['Number of Riders'], errors='coerce')
    
    # Drop rows with any NaN values after conversion
    df.dropna(inplace=True)

    # Calculate various metrics and trends
    trends = {}

    # 1. Average completed rides per simulation
    trends['Average Completed Rides per Simulation'] = df['Completed Rides'].mean()
    # Explanation: This trend shows the average number of rides completed per simulation run.
    # Example: If there are 3 simulation runs with 3, 4, and 5 completed rides respectively, the average would be (3 + 4 + 5) / 3 = 4.

    # 2. Total distance covered across all simulations
    trends['Total Distance Covered Across All Simulations'] = df['Total Distance'].sum()
    # Explanation: This trend shows the total distance covered in all completed rides across all simulations.
    # Example: If the total distances for 3 simulation runs are 12, 14, and 16, the total distance covered would be 12 + 14 + 16 = 42.

    # 3. Average earnings per simulation
    trends['Average Total USD Earned per Simulation'] = df['Total USD'].mean()
    # Explanation: This trend shows the average total earnings per simulation run.
    # Example: If the total earnings for 3 simulation runs are $30.0, $35.0, and $40.0, the average earnings would be (30.0 + 35.0 + 40.0) / 3 = $35.0.

    # 4. Average time taken per simulation
    trends['Average Total Time per Simulation'] = df['Current Time'].mean()
    # Explanation: This trend shows the average total time taken to complete all rides per simulation run.
    # Example: If the total times for 3 simulation runs are 39, 38, and 37 minutes, the average time would be (39 + 38 + 37) / 3 = 38 minutes.

    # 5. Distribution of completed rides
    trends['Distribution of Completed Rides'] = df['Completed Rides'].value_counts().to_dict()
    # Explanation: This trend shows how frequently different numbers of completed rides occur across simulations.
    # Example: If there are 3 simulation runs with 3 completed rides and 2 runs with 4 completed rides, the distribution would be {3: 3, 4: 2}.

    # 6. Correlation between total distance and total earnings
    trends['Correlation between Total Distance and Total USD'] = df['Total Distance'].corr(df['Total USD'])
    # Explanation: This trend measures the relationship between the total distance covered and the total earnings.
    # Example: A correlation of 0.9 would indicate a strong positive relationship, meaning higher distances are associated with higher earnings.

    # 7. Average number of ride requests per driver
    trends['Average Number of Ride Requests per Driver'] = df['Number of Ride Requests'].mean() / df['Number of Drivers'].mean()
    # Explanation: This trend shows the average number of ride requests each driver receives at the start of the simulation.
    # Example: If there are 3 drivers and 9 ride requests in a simulation, the average number of ride requests per driver would be 9 / 3 = 3.

    # 8. Average number of rides per rider
    trends['Average Number of Rides per Rider'] = df['Completed Rides'].sum() / df['Number of Riders'].mean()
    # Explanation: This trend shows the average number of rides each rider completes across all simulations.
    # Example: If there are 12 completed rides and 4 riders in total, the average number of rides per rider would be 12 / 4 = 3.

    # 9. Maximum earnings in a single simulation
    trends['Maximum Total USD Earned in a Single Simulation'] = df['Total USD'].max()
    # Explanation: This trend shows the highest total earnings recorded in a single simulation run.
    # Example: If the highest total earnings in a single simulation run are $50.0, this value would be $50.0.

    # 10. Variance in total time per simulation
    trends['Variance in Total Time per Simulation'] = df['Current Time'].var()
    # Explanation: This trend measures the variability in the total time taken to complete all rides across simulations.
    # Example: If the times are 39, 38, and 37 minutes, the variance would measure how much the times differ from the average (38 minutes).

    return trends

# Example usage
file_path = "/Users/sayertindall/Documents/GitHub/block.science/rideshare/research/DataViews/ResultsTracker.csv"
trends = analyze_csv(file_path)

# Print the trends
for key, value in trends.items():
    print(f"\n{key}: {value}")

# %% [markdown]
# ### Explanation of Trends with Calculations:
#
# 1. **Average Completed Rides per Simulation:**
#    - Shows the average number of rides completed per simulation run.
#    - Calculation: `df['Completed Rides'].mean()`
#    - Example: If there are 3 simulation runs with 3, 4, and 5 completed rides respectively, the average would be (3 + 4 + 5) / 3 = 4.
#
# 2. **Total Distance Covered Across All Simulations:**
#    - Shows the total distance covered in all completed rides across all simulations.
#    - Calculation: `df['Total Distance'].sum()`
#    - Example: If the total distances for 3 simulation runs are 12, 14, and 16, the total distance covered would be 12 + 14 + 16 = 42.
#
# 3. **Average Earnings per Simulation:**
#    - Shows the average total earnings per simulation run.
#    - Calculation: `df['Total USD'].mean()`
#    - Example: If the total earnings for 3 simulation runs are $30.0, $35.0, and $40.0, the average earnings would be (30.0 + 35.0 + 40.0) / 3 = $35.0.
#
# 4. **Average Time Taken per Simulation:**
#    - Shows the average total time taken to complete all rides per simulation run.
#    - Calculation: `df['Current Time'].mean()`
#    - Example: If the total times for 3 simulation runs are 39, 38, and 37 minutes, the average time would be (39 + 38 + 37) / 3 = 38 minutes.
#
# 5. **Distribution of Completed Rides:**
#    - Shows how frequently different numbers of completed rides occur across simulations.
#    - Calculation: `df['Completed Rides'].value_counts().to_dict()`
#    - Example: If there are 3 simulation runs with 3 completed rides and 2 runs with 4 completed rides, the distribution would be {3: 3, 4: 2}.
#
# 6. **Correlation between Total Distance and Total Earnings:**
#    - Measures the relationship between the total distance covered and the total earnings.
#    - Calculation: `df['Total Distance'].corr(df['Total USD'])`
#    - Example: A correlation of 0.9 would indicate a strong positive relationship, meaning higher distances are associated with higher earnings.
#
# 7. **Average Number of Ride Requests per Driver:**
#    - Shows the average number of ride requests each driver receives at the start of the simulation.
#    - Calculation: `df['Number of Ride Requests'].mean() / df['Number of Drivers'].mean()`
#    - Example: If there are 3 drivers and 9 ride requests in a simulation, the average number of ride requests per driver would be 9 / 3 = 3.
#
# 8. **Average Number of Rides per Rider:**
#    - Shows the average number of rides completed by each rider across all simulations.
#    - Calculation: `df['Completed Rides'].sum() / df['Number of Riders'].mean()`
#    - Example: If there are 12 completed rides and 4 riders in total, the average number of rides per rider would be 12 / 4 = 3.
#
# 9. **Maximum Earnings in a Single Simulation:**
#    - Shows the highest total earnings recorded in a single simulation run.
#    - Calculation: `df['Total USD'].max()`
#    - Example: If the highest total earnings in a single simulation run are $50.0, this value would be $50.0.
#
# 10. **Variance in Total Time per Simulation:**
#     - Measures the variability in the total time taken to complete all rides across simulations.
#     - Calculation: `df['Current Time'].var()`
#     - Example: If the times are 39, 38, and 37 minutes, the variance would measure how much the times differ from the average (38 minutes).

# %%
seed = 100
upper_limit = 75000
file_path = "/Users/sayertindall/Documents/GitHub/block.science/rideshare/research/DataViews/ResultsTracker2.csv"
# %run moving.py {seed} {upper_limit} {file_path}
# Out:
# Grid dimensions: 15 15
# Number of Zones: 225
# Number of Nodes: 225
# Number of Edges: 840
# Number of Riders: 1884
# Number of Drivers: 1831
# Number of Ride Requests: 1884
#
#
# State recorded
# Processing event: Event(t=1, action='Request Ride', spaces={'ride_id': 1192}) at time 1
# Handling ride request event for ride 1192 at time 1
# Travel time: 38, Cost: 38.0
# Driver Driver 0 assigned to ride 1192 at time 39
# State recorded
# Processing event: Event(t=2, action='Request Ride', spaces={'ride_id': 1417}) at time 2
# Handling ride request event for ride 1417 at time 2
# Travel time: 59, Cost: 59.0
# Driver Driver 1 assigned to ride 1417 at time 61
# State recorded
# Processing event: Event(t=3, action='Request Ride', spaces={'ride_id': 966}) at time 3
# Handling ride request event for ride 966 at time 3
# Travel time: 28, Cost: 28.0
# Driver Driver 2 assigned to ride 966 at time 31
# State recorded
# State recorded
# State recorded
# Processing event: Event(t=6, action='Request Ride', spaces={'ride_id': 1363}) at time 6
# Handling ride request event for ride 1363 at time 6
# Travel time: 9, Cost: 9.0
# Driver Driver 3 assigned to ride 1363 at time 15
# State recorded
# Processing event: Event(t=7, action='Request Ride', spaces={'ride_id': 478}) at time 7
# Handling ride request event for ride 478 at time 7
# Travel time: 16, Cost: 16.0
# Driver Driver 4 assigned to ride 478 at time 23
# Processing event: Event(t=7, action='Request Ride', spaces={'ride_id': 115}) at time 7
# Handling ride request event for ride 115 at time 7
# Travel time: 28, Cost: 28.0
# Driver Driver 5 assigned to ride 115 at time 35
# State recorded
# Processing event: Event(t=8, action='Request Ride', spaces={'ride_id': 1065}) at time 8
# Handling ride request event for ride 1065 at time 8
# Travel time: 43, Cost: 43.0
# Driver Driver 6 assigned to ride 1065 at time 51
# State recorded
# State recorded
# Processing event: Event(t=10, action='Request Ride', spaces={'ride_id': 213}) at time 10
# Handling ride request event for ride 213 at time 10
# Travel time: 4, Cost: 4.0
# Driver Driver 7 assigned to ride 213 at time 14
# Processing event: Event(t=10, action='Request Ride', spaces={'ride_id': 1269}) at time 10
# Handling ride request event for ride 1269 at time 10
# Travel time: 25, Cost: 25.0
# Driver Driver 8 assigned to ride 1269 at time 35
# State recorded
# State recorded
# Processing event: Event(t=12, action='Request Ride', spaces={'ride_id': 160}) at time 12
# Handling ride request event for ride 160 at time 12
# Travel time: 67, Cost: 67.0
# Driver Driver 9 assigned to ride 160 at time 79
# State recorded
# Processing event: Event(t=13, action='Request Ride', spaces={'ride_id': 1732}) at time 13
# Handling ride request event for ride 1732 at time 13
# Travel time: 12, Cost: 12.0
# Driver Driver 10 assigned to ride 1732 at time 25
# Processing event: Event(t=13, action='Request Ride', spaces={'ride_id': 783}) at time 13
# Handling ride request event for ride 783 at time 13
# Travel time: 8, Cost: 8.0
# Driver Driver 11 assigned to ride 783 at time 21
# Processing event: Event(t=13, action='Request Ride', spaces={'ride_id': 387}) at time 13
# Handling ride request event for ride 387 at time 13
# Travel time: 56, Cost: 56.0
# Driver Driver 12 assigned to ride 387 at time 69
# State recorded
# Processing event: Event(t=14, action='Driver Assigned', spaces={'ride_id': 213, 'driver_id': 'Driver 7'}) at time 14
# Driver Driver 7 arrived at pickup for ride 213 at time 14
# Ride 213 in progress, will complete at time 46
# State recorded
# Processing event: Event(t=15, action='Driver Assigned', spaces={'ride_id': 1363, 'driver_id': 'Driver 3'}) at time 15
# Driver Driver 3 arrived at pickup for ride 1363 at time 15
# Ride 1363 in progress, will complete at time 33
# State recorded
# Processing event: Event(t=16, action='Request Ride', spaces={'ride_id': 1868}) at time 16
# Handling ride request event for ride 1868 at time 16
# Travel time: 35, Cost: 35.0
# Driver Driver 13 assigned to ride 1868 at time 51
# Processing event: Event(t=16, action='Request Ride', spaces={'ride_id': 613}) at time 16
# Handling ride request event for ride 613 at time 16
# Travel time: 24, Cost: 24.0
# Driver Driver 14 assigned to ride 613 at time 40
# Processing event: Event(t=16, action='Request Ride', spaces={'ride_id': 547}) at time 16
# Handling ride request event for ride 547 at time 16
# Travel time: 53, Cost: 53.0
# Driver Driver 15 assigned to ride 547 at time 69
# State recorded
# Processing event: Event(t=17, action='Request Ride', spaces={'ride_id': 1315}) at time 17
# Handling ride request event for ride 1315 at time 17
# Travel time: 26, Cost: 26.0
# Driver Driver 16 assigned to ride 1315 at time 43
# State recorded
# Processing event: Event(t=18, action='Request Ride', spaces={'ride_id': 1060}) at time 18
# Handling ride request event for ride 1060 at time 18
# Travel time: 15, Cost: 15.0
# Driver Driver 17 assigned to ride 1060 at time 33
# State recorded
# State recorded
# Processing event: Event(t=20, action='Request Ride', spaces={'ride_id': 1789}) at time 20
# Handling ride request event for ride 1789 at time 20
# Travel time: 22, Cost: 22.0
# Driver Driver 18 assigned to ride 1789 at time 42
# State recorded
# Processing event: Event(t=21, action='Driver Assigned', spaces={'ride_id': 783, 'driver_id': 'Driver 11'}) at time 21
# Driver Driver 11 arrived at pickup for ride 783 at time 21
# Ride 783 in progress, will complete at time 77
# State recorded
# Processing event: Event(t=22, action='Request Ride', spaces={'ride_id': 1829}) at time 22
# Handling ride request event for ride 1829 at time 22
# Travel time: 29, Cost: 29.0
# Driver Driver 19 assigned to ride 1829 at time 51
# Processing event: Event(t=22, action='Request Ride', spaces={'ride_id': 1399}) at time 22
# Handling ride request event for ride 1399 at time 22
# Travel time: 20, Cost: 20.0
# Driver Driver 20 assigned to ride 1399 at time 42
# State recorded
# Processing event: Event(t=23, action='Driver Assigned', spaces={'ride_id': 478, 'driver_id': 'Driver 4'}) at time 23
# Driver Driver 4 arrived at pickup for ride 478 at time 23
# Ride 478 in progress, will complete at time 87
# State recorded
# State recorded
# Processing event: Event(t=25, action='Driver Assigned', spaces={'ride_id': 1732, 'driver_id': 'Driver 10'}) at time 25
# Driver Driver 10 arrived at pickup for ride 1732 at time 25
# Ride 1732 in progress, will complete at time 42
# Processing event: Event(t=25, action='Request Ride', spaces={'ride_id': 66}) at time 25
# Handling ride request event for ride 66 at time 25
# Travel time: 59, Cost: 59.0
# Driver Driver 21 assigned to ride 66 at time 84
# State recorded
# Processing event: Event(t=26, action='Request Ride', spaces={'ride_id': 98}) at time 26
# Handling ride request event for ride 98 at time 26
# Travel time: 28, Cost: 28.0
# Driver Driver 22 assigned to ride 98 at time 54
# State recorded
# Processing event: Event(t=27, action='Request Ride', spaces={'ride_id': 395}) at time 27
# Handling ride request event for ride 395 at time 27
# Travel time: 23, Cost: 23.0
# Driver Driver 23 assigned to ride 395 at time 50
# State recorded
# State recorded
# State recorded
# State recorded
# Processing event: Event(t=31, action='Driver Assigned', spaces={'ride_id': 966, 'driver_id': 'Driver 2'}) at time 31
# Driver Driver 2 arrived at pickup for ride 966 at time 31
# Ride 966 in progress, will complete at time 59
# Processing event: Event(t=31, action='Request Ride', spaces={'ride_id': 845}) at time 31
# Handling ride request event for ride 845 at time 31
# Travel time: 29, Cost: 29.0
# Driver Driver 24 assigned to ride 845 at time 60
# Processing event: Event(t=31, action='Request Ride', spaces={'ride_id': 1646}) at time 31
# Handling ride request event for ride 1646 at time 31
# Travel time: 43, Cost: 43.0
# Driver Driver 25 assigned to ride 1646 at time 74
# State recorded
# Processing event: Event(t=32, action='Request Ride', spaces={'ride_id': 994}) at time 32
# Handling ride request event for ride 994 at time 32
# Travel time: 41, Cost: 41.0
# Driver Driver 26 assigned to ride 994 at time 73
# Processing event: Event(t=32, action='Request Ride', spaces={'ride_id': 643}) at time 32
# Handling ride request event for ride 643 at time 32
# Travel time: 36, Cost: 36.0
# Driver Driver 27 assigned to ride 643 at time 68
# State recorded
# Processing event: Event(t=33, action='Complete Ride', spaces={'ride_id': 1363, 'driver_id': 'Driver 3'}) at time 33
# Completing ride 1363 by driver Driver 3 at time 33
# Ride 1363 completed
# Processing event: Event(t=33, action='Driver Assigned', spaces={'ride_id': 1060, 'driver_id': 'Driver 17'}) at time 33
# Driver Driver 17 arrived at pickup for ride 1060 at time 33
# Ride 1060 in progress, will complete at time 69
# Processing event: Event(t=33, action='Request Ride', spaces={'ride_id': 252}) at time 33
# Handling ride request event for ride 252 at time 33
# Travel time: 26, Cost: 26.0
# Driver Driver 3 assigned to ride 252 at time 59
# Processing event: Event(t=33, action='Request Ride', spaces={'ride_id': 268}) at time 33
# Handling ride request event for ride 268 at time 33
# Travel time: 38, Cost: 38.0
# Driver Driver 28 assigned to ride 268 at time 71
# State recorded
# State recorded
# Processing event: Event(t=35, action='Driver Assigned', spaces={'ride_id': 115, 'driver_id': 'Driver 5'}) at time 35
# Driver Driver 5 arrived at pickup for ride 115 at time 35
# Ride 115 in progress, will complete at time 84
# Processing event: Event(t=35, action='Driver Assigned', spaces={'ride_id': 1269, 'driver_id': 'Driver 8'}) at time 35
# Driver Driver 8 arrived at pickup for ride 1269 at time 35
# Ride 1269 in progress, will complete at time 84
# Processing event: Event(t=35, action='Request Ride', spaces={'ride_id': 1772}) at time 35
# Handling ride request event for ride 1772 at time 35
# Travel time: 46, Cost: 46.0
# Driver Driver 29 assigned to ride 1772 at time 81
# Processing event: Event(t=35, action='Request Ride', spaces={'ride_id': 53}) at time 35
# Handling ride request event for ride 53 at time 35
# Travel time: 47, Cost: 47.0
# Driver Driver 30 assigned to ride 53 at time 82
# Processing event: Event(t=35, action='Request Ride', spaces={'ride_id': 367}) at time 35
# Handling ride request event for ride 367 at time 35
# Travel time: 21, Cost: 21.0
# Driver Driver 31 assigned to ride 367 at time 56
# State recorded
# Processing event: Event(t=36, action='Request Ride', spaces={'ride_id': 1021}) at time 36
# Handling ride request event for ride 1021 at time 36
# Travel time: 24, Cost: 24.0
# Driver Driver 32 assigned to ride 1021 at time 60
# Processing event: Event(t=36, action='Request Ride', spaces={'ride_id': 1594}) at time 36
# Handling ride request event for ride 1594 at time 36
# Travel time: 8, Cost: 8.0
# Driver Driver 33 assigned to ride 1594 at time 44
# State recorded
# Processing event: Event(t=37, action='Request Ride', spaces={'ride_id': 508}) at time 37
# Handling ride request event for ride 508 at time 37
# Travel time: 34, Cost: 34.0
# Driver Driver 34 assigned to ride 508 at time 71
# State recorded
# Processing event: Event(t=38, action='Request Ride', spaces={'ride_id': 518}) at time 38
# Handling ride request event for ride 518 at time 38
# Travel time: 42, Cost: 42.0
# Driver Driver 35 assigned to ride 518 at time 80
# State recorded
# Processing event: Event(t=39, action='Driver Assigned', spaces={'ride_id': 1192, 'driver_id': 'Driver 0'}) at time 39
# Driver Driver 0 arrived at pickup for ride 1192 at time 39
# Ride 1192 in progress, will complete at time 90
# Processing event: Event(t=39, action='Request Ride', spaces={'ride_id': 1843}) at time 39
# Handling ride request event for ride 1843 at time 39
# Travel time: 45, Cost: 45.0
# Driver Driver 36 assigned to ride 1843 at time 84
# Processing event: Event(t=39, action='Request Ride', spaces={'ride_id': 1694}) at time 39
# Handling ride request event for ride 1694 at time 39
# Travel time: 23, Cost: 23.0
# Driver Driver 37 assigned to ride 1694 at time 62
# Processing event: Event(t=39, action='Request Ride', spaces={'ride_id': 943}) at time 39
# Handling ride request event for ride 943 at time 39
# Travel time: 2, Cost: 2.0
# Driver Driver 38 assigned to ride 943 at time 41
# State recorded
# Processing event: Event(t=40, action='Driver Assigned', spaces={'ride_id': 613, 'driver_id': 'Driver 14'}) at time 40
# Driver Driver 14 arrived at pickup for ride 613 at time 40
# Ride 613 in progress, will complete at time 50
# State recorded
# Processing event: Event(t=41, action='Driver Assigned', spaces={'ride_id': 943, 'driver_id': 'Driver 38'}) at time 41
# Driver Driver 38 arrived at pickup for ride 943 at time 41
# Ride 943 in progress, will complete at time 53
# Processing event: Event(t=41, action='Request Ride', spaces={'ride_id': 668}) at time 41
# Handling ride request event for ride 668 at time 41
# Travel time: 41, Cost: 41.0
# Driver Driver 39 assigned to ride 668 at time 82
# State recorded
# Processing event: Event(t=42, action='Complete Ride', spaces={'ride_id': 1732, 'driver_id': 'Driver 10'}) at time 42
# Completing ride 1732 by driver Driver 10 at time 42
# Ride 1732 completed
# Processing event: Event(t=42, action='Driver Assigned', spaces={'ride_id': 1789, 'driver_id': 'Driver 18'}) at time 42
# Driver Driver 18 arrived at pickup for ride 1789 at time 42
# Ride 1789 in progress, will complete at time 81
# Processing event: Event(t=42, action='Driver Assigned', spaces={'ride_id': 1399, 'driver_id': 'Driver 20'}) at time 42
# Driver Driver 20 arrived at pickup for ride 1399 at time 42
# Ride 1399 in progress, will complete at time 96
# State recorded
# Processing event: Event(t=43, action='Driver Assigned', spaces={'ride_id': 1315, 'driver_id': 'Driver 16'}) at time 43
# Driver Driver 16 arrived at pickup for ride 1315 at time 43
# Ride 1315 in progress, will complete at time 93
# State recorded
# Processing event: Event(t=44, action='Driver Assigned', spaces={'ride_id': 1594, 'driver_id': 'Driver 33'}) at time 44
# Driver Driver 33 arrived at pickup for ride 1594 at time 44
# Ride 1594 in progress, will complete at time 70
# State recorded
# Processing event: Event(t=45, action='Request Ride', spaces={'ride_id': 1803}) at time 45
# Handling ride request event for ride 1803 at time 45
# Travel time: 28, Cost: 28.0
# Driver Driver 10 assigned to ride 1803 at time 73
# Processing event: Event(t=45, action='Request Ride', spaces={'ride_id': 1214}) at time 45
# Handling ride request event for ride 1214 at time 45
# Travel time: 6, Cost: 6.0
# Driver Driver 40 assigned to ride 1214 at time 51
# State recorded
# Processing event: Event(t=46, action='Complete Ride', spaces={'ride_id': 213, 'driver_id': 'Driver 7'}) at time 46
# Completing ride 213 by driver Driver 7 at time 46
# Ride 213 completed
# Processing event: Event(t=46, action='Request Ride', spaces={'ride_id': 1440}) at time 46
# Handling ride request event for ride 1440 at time 46
# Travel time: 60, Cost: 60.0
# Driver Driver 7 assigned to ride 1440 at time 106
# State recorded
# State recorded
# State recorded
# Processing event: Event(t=49, action='Request Ride', spaces={'ride_id': 461}) at time 49
# Handling ride request event for ride 461 at time 49
# Travel time: 22, Cost: 22.0
# Driver Driver 41 assigned to ride 461 at time 71
# State recorded
# Processing event: Event(t=50, action='Complete Ride', spaces={'ride_id': 613, 'driver_id': 'Driver 14'}) at time 50
# Completing ride 613 by driver Driver 14 at time 50
# Ride 613 completed
# Processing event: Event(t=50, action='Driver Assigned', spaces={'ride_id': 395, 'driver_id': 'Driver 23'}) at time 50
# Driver Driver 23 arrived at pickup for ride 395 at time 50
# Ride 395 in progress, will complete at time 71
# State recorded
# Processing event: Event(t=51, action='Driver Assigned', spaces={'ride_id': 1214, 'driver_id': 'Driver 40'}) at time 51
# Driver Driver 40 arrived at pickup for ride 1214 at time 51
# Ride 1214 in progress, will complete at time 96
# Processing event: Event(t=51, action='Driver Assigned', spaces={'ride_id': 1829, 'driver_id': 'Driver 19'}) at time 51
# Driver Driver 19 arrived at pickup for ride 1829 at time 51
# Ride 1829 in progress, will complete at time 64
# Processing event: Event(t=51, action='Driver Assigned', spaces={'ride_id': 1065, 'driver_id': 'Driver 6'}) at time 51
# Driver Driver 6 arrived at pickup for ride 1065 at time 51
# Ride 1065 in progress, will complete at time 68
# Processing event: Event(t=51, action='Driver Assigned', spaces={'ride_id': 1868, 'driver_id': 'Driver 13'}) at time 51
# Driver Driver 13 arrived at pickup for ride 1868 at time 51
# Ride 1868 in progress, will complete at time 80
# State recorded
# Processing event: Event(t=52, action='Request Ride', spaces={'ride_id': 977}) at time 52
# Handling ride request event for ride 977 at time 52
# Travel time: 49, Cost: 49.0
# Driver Driver 14 assigned to ride 977 at time 101
# Processing event: Event(t=52, action='Request Ride', spaces={'ride_id': 945}) at time 52
# Handling ride request event for ride 945 at time 52
# Travel time: 32, Cost: 32.0
# Driver Driver 42 assigned to ride 945 at time 84
# Processing event: Event(t=52, action='Request Ride', spaces={'ride_id': 1227}) at time 52
# Handling ride request event for ride 1227 at time 52
# Travel time: 55, Cost: 55.0
# Driver Driver 43 assigned to ride 1227 at time 107
# Processing event: Event(t=52, action='Request Ride', spaces={'ride_id': 4}) at time 52
# Handling ride request event for ride 4 at time 52
# Travel time: 31, Cost: 31.0
# Driver Driver 44 assigned to ride 4 at time 83
# State recorded
# Processing event: Event(t=53, action='Complete Ride', spaces={'ride_id': 943, 'driver_id': 'Driver 38'}) at time 53
# Completing ride 943 by driver Driver 38 at time 53
# Ride 943 completed
# Processing event: Event(t=53, action='Request Ride', spaces={'ride_id': 569}) at time 53
# Handling ride request event for ride 569 at time 53
# Travel time: 18, Cost: 18.0
# Driver Driver 38 assigned to ride 569 at time 71
# State recorded
# Processing event: Event(t=54, action='Driver Assigned', spaces={'ride_id': 98, 'driver_id': 'Driver 22'}) at time 54
# Driver Driver 22 arrived at pickup for ride 98 at time 54
# Ride 98 in progress, will complete at time 85
# State recorded
# State recorded
# Processing event: Event(t=56, action='Driver Assigned', spaces={'ride_id': 367, 'driver_id': 'Driver 31'}) at time 56
# Driver Driver 31 arrived at pickup for ride 367 at time 56
# Ride 367 in progress, will complete at time 108
# Processing event: Event(t=56, action='Request Ride', spaces={'ride_id': 599}) at time 56
# Handling ride request event for ride 599 at time 56
# Travel time: 66, Cost: 66.0
# Driver Driver 45 assigned to ride 599 at time 122
# State recorded
# Processing event: Event(t=57, action='Request Ride', spaces={'ride_id': 1373}) at time 57
# Handling ride request event for ride 1373 at time 57
# Travel time: 28, Cost: 28.0
# Driver Driver 46 assigned to ride 1373 at time 85
# Processing event: Event(t=57, action='Request Ride', spaces={'ride_id': 1044}) at time 57
# Handling ride request event for ride 1044 at time 57
# Travel time: 43, Cost: 43.0
# Driver Driver 47 assigned to ride 1044 at time 100
# State recorded
# Processing event: Event(t=58, action='Request Ride', spaces={'ride_id': 1853}) at time 58
# Handling ride request event for ride 1853 at time 58
# Travel time: 43, Cost: 43.0
# Driver Driver 48 assigned to ride 1853 at time 101
# Processing event: Event(t=58, action='Request Ride', spaces={'ride_id': 1674}) at time 58
# Handling ride request event for ride 1674 at time 58
# Travel time: 13, Cost: 13.0
# Driver Driver 49 assigned to ride 1674 at time 71
# Processing event: Event(t=58, action='Request Ride', spaces={'ride_id': 1275}) at time 58
# Handling ride request event for ride 1275 at time 58
# Travel time: 29, Cost: 29.0
# Driver Driver 50 assigned to ride 1275 at time 87
# State recorded
# Processing event: Event(t=59, action='Complete Ride', spaces={'ride_id': 966, 'driver_id': 'Driver 2'}) at time 59
# Completing ride 966 by driver Driver 2 at time 59
# Ride 966 completed
# Processing event: Event(t=59, action='Driver Assigned', spaces={'ride_id': 252, 'driver_id': 'Driver 3'}) at time 59
# Driver Driver 3 arrived at pickup for ride 252 at time 59
# Ride 252 in progress, will complete at time 77
# Processing event: Event(t=59, action='Request Ride', spaces={'ride_id': 1687}) at time 59
# Handling ride request event for ride 1687 at time 59
# Travel time: 39, Cost: 39.0
# Driver Driver 2 assigned to ride 1687 at time 98
# Processing event: Event(t=59, action='Request Ride', spaces={'ride_id': 1488}) at time 59
# Handling ride request event for ride 1488 at time 59
# Travel time: 39, Cost: 39.0
# Driver Driver 51 assigned to ride 1488 at time 98
# Processing event: Event(t=59, action='Request Ride', spaces={'ride_id': 626}) at time 59
# Handling ride request event for ride 626 at time 59
# Travel time: 47, Cost: 47.0
# Driver Driver 52 assigned to ride 626 at time 106
# State recorded
# Processing event: Event(t=60, action='Driver Assigned', spaces={'ride_id': 845, 'driver_id': 'Driver 24'}) at time 60
# Driver Driver 24 arrived at pickup for ride 845 at time 60
# Ride 845 in progress, will complete at time 98
# Processing event: Event(t=60, action='Driver Assigned', spaces={'ride_id': 1021, 'driver_id': 'Driver 32'}) at time 60
# Driver Driver 32 arrived at pickup for ride 1021 at time 60
# Ride 1021 in progress, will complete at time 85
# Processing event: Event(t=60, action='Request Ride', spaces={'ride_id': 659}) at time 60
# Handling ride request event for ride 659 at time 60
# Travel time: 44, Cost: 44.0
# Driver Driver 53 assigned to ride 659 at time 104
# State recorded
# Processing event: Event(t=61, action='Driver Assigned', spaces={'ride_id': 1417, 'driver_id': 'Driver 1'}) at time 61
# Driver Driver 1 arrived at pickup for ride 1417 at time 61
# Ride 1417 in progress, will complete at time 74
# Processing event: Event(t=61, action='Request Ride', spaces={'ride_id': 333}) at time 61
# Handling ride request event for ride 333 at time 61
# Travel time: 50, Cost: 50.0
# Driver Driver 54 assigned to ride 333 at time 111
# State recorded
# Processing event: Event(t=62, action='Driver Assigned', spaces={'ride_id': 1694, 'driver_id': 'Driver 37'}) at time 62
# Driver Driver 37 arrived at pickup for ride 1694 at time 62
# Ride 1694 in progress, will complete at time 91
# Processing event: Event(t=62, action='Request Ride', spaces={'ride_id': 1261}) at time 62
# Handling ride request event for ride 1261 at time 62
# Travel time: 70, Cost: 70.0
# Driver Driver 55 assigned to ride 1261 at time 132
# State recorded
# Processing event: Event(t=63, action='Request Ride', spaces={'ride_id': 1432}) at time 63
# Handling ride request event for ride 1432 at time 63
# Travel time: 30, Cost: 30.0
# Driver Driver 56 assigned to ride 1432 at time 93
# State recorded
# Processing event: Event(t=64, action='Complete Ride', spaces={'ride_id': 1829, 'driver_id': 'Driver 19'}) at time 64
# Completing ride 1829 by driver Driver 19 at time 64
# Ride 1829 completed
# Processing event: Event(t=64, action='Request Ride', spaces={'ride_id': 1631}) at time 64
# Handling ride request event for ride 1631 at time 64
# Travel time: 10, Cost: 10.0
# Driver Driver 19 assigned to ride 1631 at time 74
# State recorded
# Processing event: Event(t=65, action='Request Ride', spaces={'ride_id': 1446}) at time 65
# Handling ride request event for ride 1446 at time 65
# Travel time: 55, Cost: 55.0
# Driver Driver 57 assigned to ride 1446 at time 120
# Processing event: Event(t=65, action='Request Ride', spaces={'ride_id': 564}) at time 65
# Handling ride request event for ride 564 at time 65
# Travel time: 44, Cost: 44.0
# Driver Driver 58 assigned to ride 564 at time 109
# State recorded
# State recorded
# State recorded
# Processing event: Event(t=68, action='Complete Ride', spaces={'ride_id': 1065, 'driver_id': 'Driver 6'}) at time 68
# Completing ride 1065 by driver Driver 6 at time 68
# Ride 1065 completed
# Processing event: Event(t=68, action='Driver Assigned', spaces={'ride_id': 643, 'driver_id': 'Driver 27'}) at time 68
# Driver Driver 27 arrived at pickup for ride 643 at time 68
# Ride 643 in progress, will complete at time 103
# Processing event: Event(t=68, action='Request Ride', spaces={'ride_id': 1133}) at time 68
# Handling ride request event for ride 1133 at time 68
# Travel time: 21, Cost: 21.0
# Driver Driver 6 assigned to ride 1133 at time 89
# State recorded
# Processing event: Event(t=69, action='Complete Ride', spaces={'ride_id': 1060, 'driver_id': 'Driver 17'}) at time 69
# Completing ride 1060 by driver Driver 17 at time 69
# Ride 1060 completed
# Processing event: Event(t=69, action='Driver Assigned', spaces={'ride_id': 387, 'driver_id': 'Driver 12'}) at time 69
# Driver Driver 12 arrived at pickup for ride 387 at time 69
# Ride 387 in progress, will complete at time 112
# Processing event: Event(t=69, action='Driver Assigned', spaces={'ride_id': 547, 'driver_id': 'Driver 15'}) at time 69
# Driver Driver 15 arrived at pickup for ride 547 at time 69
# Ride 547 in progress, will complete at time 82
# State recorded
# Processing event: Event(t=70, action='Complete Ride', spaces={'ride_id': 1594, 'driver_id': 'Driver 33'}) at time 70
# Completing ride 1594 by driver Driver 33 at time 70
# Ride 1594 completed
# Processing event: Event(t=70, action='Request Ride', spaces={'ride_id': 739}) at time 70
# Handling ride request event for ride 739 at time 70
# Travel time: 40, Cost: 40.0
# Driver Driver 17 assigned to ride 739 at time 110
# Processing event: Event(t=70, action='Request Ride', spaces={'ride_id': 359}) at time 70
# Handling ride request event for ride 359 at time 70
# Travel time: 15, Cost: 15.0
# Driver Driver 33 assigned to ride 359 at time 85
# Processing event: Event(t=70, action='Request Ride', spaces={'ride_id': 170}) at time 70
# Handling ride request event for ride 170 at time 70
# Travel time: 13, Cost: 13.0
# Driver Driver 59 assigned to ride 170 at time 83
# State recorded
# Processing event: Event(t=71, action='Complete Ride', spaces={'ride_id': 395, 'driver_id': 'Driver 23'}) at time 71
# Completing ride 395 by driver Driver 23 at time 71
# Ride 395 completed
# Processing event: Event(t=71, action='Driver Assigned', spaces={'ride_id': 461, 'driver_id': 'Driver 41'}) at time 71
# Driver Driver 41 arrived at pickup for ride 461 at time 71
# Ride 461 in progress, will complete at time 154
# Processing event: Event(t=71, action='Driver Assigned', spaces={'ride_id': 569, 'driver_id': 'Driver 38'}) at time 71
# Driver Driver 38 arrived at pickup for ride 569 at time 71
# Ride 569 in progress, will complete at time 123
# Processing event: Event(t=71, action='Driver Assigned', spaces={'ride_id': 1674, 'driver_id': 'Driver 49'}) at time 71
# Driver Driver 49 arrived at pickup for ride 1674 at time 71
# Ride 1674 in progress, will complete at time 139
# Processing event: Event(t=71, action='Driver Assigned', spaces={'ride_id': 268, 'driver_id': 'Driver 28'}) at time 71
# Driver Driver 28 arrived at pickup for ride 268 at time 71
# Ride 268 in progress, will complete at time 122
# Processing event: Event(t=71, action='Driver Assigned', spaces={'ride_id': 508, 'driver_id': 'Driver 34'}) at time 71
# Driver Driver 34 arrived at pickup for ride 508 at time 71
# Ride 508 in progress, will complete at time 109
# State recorded
# State recorded
# Processing event: Event(t=73, action='Driver Assigned', spaces={'ride_id': 994, 'driver_id': 'Driver 26'}) at time 73
# Driver Driver 26 arrived at pickup for ride 994 at time 73
# Ride 994 in progress, will complete at time 89
# Processing event: Event(t=73, action='Driver Assigned', spaces={'ride_id': 1803, 'driver_id': 'Driver 10'}) at time 73
# Driver Driver 10 arrived at pickup for ride 1803 at time 73
# Ride 1803 in progress, will complete at time 80
# Processing event: Event(t=73, action='Request Ride', spaces={'ride_id': 497}) at time 73
# Handling ride request event for ride 497 at time 73
# Travel time: 47, Cost: 47.0
# Driver Driver 23 assigned to ride 497 at time 120
# Processing event: Event(t=73, action='Request Ride', spaces={'ride_id': 1810}) at time 73
# Handling ride request event for ride 1810 at time 73
# Travel time: 43, Cost: 43.0
# Driver Driver 60 assigned to ride 1810 at time 116
# State recorded
# Processing event: Event(t=74, action='Complete Ride', spaces={'ride_id': 1417, 'driver_id': 'Driver 1'}) at time 74
# Completing ride 1417 by driver Driver 1 at time 74
# Ride 1417 completed
# Processing event: Event(t=74, action='Driver Assigned', spaces={'ride_id': 1631, 'driver_id': 'Driver 19'}) at time 74
# Driver Driver 19 arrived at pickup for ride 1631 at time 74
# Ride 1631 in progress, will complete at time 128
# Processing event: Event(t=74, action='Driver Assigned', spaces={'ride_id': 1646, 'driver_id': 'Driver 25'}) at time 74
# Driver Driver 25 arrived at pickup for ride 1646 at time 74
# Ride 1646 in progress, will complete at time 131
# Processing event: Event(t=74, action='Request Ride', spaces={'ride_id': 667}) at time 74
# Handling ride request event for ride 667 at time 74
# Travel time: 39, Cost: 39.0
# Driver Driver 1 assigned to ride 667 at time 113
# State recorded
# State recorded
# State recorded
# Processing event: Event(t=77, action='Complete Ride', spaces={'ride_id': 252, 'driver_id': 'Driver 3'}) at time 77
# Completing ride 252 by driver Driver 3 at time 77
# Ride 252 completed
# Processing event: Event(t=77, action='Complete Ride', spaces={'ride_id': 783, 'driver_id': 'Driver 11'}) at time 77
# Completing ride 783 by driver Driver 11 at time 77
# Ride 783 completed
# State recorded
# State recorded
# Processing event: Event(t=79, action='Driver Assigned', spaces={'ride_id': 160, 'driver_id': 'Driver 9'}) at time 79
# Driver Driver 9 arrived at pickup for ride 160 at time 79
# Ride 160 in progress, will complete at time 109
# Processing event: Event(t=79, action='Request Ride', spaces={'ride_id': 256}) at time 79
# Handling ride request event for ride 256 at time 79
# Travel time: 33, Cost: 33.0
# Driver Driver 3 assigned to ride 256 at time 112
# State recorded
# Processing event: Event(t=80, action='Complete Ride', spaces={'ride_id': 1803, 'driver_id': 'Driver 10'}) at time 80
# Completing ride 1803 by driver Driver 10 at time 80
# Ride 1803 completed
# Processing event: Event(t=80, action='Complete Ride', spaces={'ride_id': 1868, 'driver_id': 'Driver 13'}) at time 80
# Completing ride 1868 by driver Driver 13 at time 80
# Ride 1868 completed
# Processing event: Event(t=80, action='Driver Assigned', spaces={'ride_id': 518, 'driver_id': 'Driver 35'}) at time 80
# Driver Driver 35 arrived at pickup for ride 518 at time 80
# Ride 518 in progress, will complete at time 100
# State recorded
# Processing event: Event(t=81, action='Complete Ride', spaces={'ride_id': 1789, 'driver_id': 'Driver 18'}) at time 81
# Completing ride 1789 by driver Driver 18 at time 81
# Ride 1789 completed
# Processing event: Event(t=81, action='Driver Assigned', spaces={'ride_id': 1772, 'driver_id': 'Driver 29'}) at time 81
# Driver Driver 29 arrived at pickup for ride 1772 at time 81
# Ride 1772 in progress, will complete at time 106
# State recorded
# Processing event: Event(t=82, action='Complete Ride', spaces={'ride_id': 547, 'driver_id': 'Driver 15'}) at time 82
# Completing ride 547 by driver Driver 15 at time 82
# Ride 547 completed
# Processing event: Event(t=82, action='Driver Assigned', spaces={'ride_id': 668, 'driver_id': 'Driver 39'}) at time 82
# Driver Driver 39 arrived at pickup for ride 668 at time 82
# Ride 668 in progress, will complete at time 128
# Processing event: Event(t=82, action='Driver Assigned', spaces={'ride_id': 53, 'driver_id': 'Driver 30'}) at time 82
# Driver Driver 30 arrived at pickup for ride 53 at time 82
# Ride 53 in progress, will complete at time 95
# State recorded
# Processing event: Event(t=83, action='Driver Assigned', spaces={'ride_id': 170, 'driver_id': 'Driver 59'}) at time 83
# Driver Driver 59 arrived at pickup for ride 170 at time 83
# Ride 170 in progress, will complete at time 147
# Processing event: Event(t=83, action='Driver Assigned', spaces={'ride_id': 4, 'driver_id': 'Driver 44'}) at time 83
# Driver Driver 44 arrived at pickup for ride 4 at time 83
# Ride 4 in progress, will complete at time 128
# State recorded
# Processing event: Event(t=84, action='Complete Ride', spaces={'ride_id': 1269, 'driver_id': 'Driver 8'}) at time 84
# Completing ride 1269 by driver Driver 8 at time 84
# Ride 1269 completed
# Processing event: Event(t=84, action='Complete Ride', spaces={'ride_id': 115, 'driver_id': 'Driver 5'}) at time 84
# Completing ride 115 by driver Driver 5 at time 84
# Ride 115 completed
# Processing event: Event(t=84, action='Driver Assigned', spaces={'ride_id': 66, 'driver_id': 'Driver 21'}) at time 84
# Driver Driver 21 arrived at pickup for ride 66 at time 84
# Ride 66 in progress, will complete at time 137
# Processing event: Event(t=84, action='Driver Assigned', spaces={'ride_id': 1843, 'driver_id': 'Driver 36'}) at time 84
# Driver Driver 36 arrived at pickup for ride 1843 at time 84
# Ride 1843 in progress, will complete at time 145
# Processing event: Event(t=84, action='Driver Assigned', spaces={'ride_id': 945, 'driver_id': 'Driver 42'}) at time 84
# Driver Driver 42 arrived at pickup for ride 945 at time 84
# Ride 945 in progress, will complete at time 121
# Processing event: Event(t=84, action='Request Ride', spaces={'ride_id': 1136}) at time 84
# Handling ride request event for ride 1136 at time 84
# Travel time: 12, Cost: 12.0
# Driver Driver 5 assigned to ride 1136 at time 96
# State recorded
# Processing event: Event(t=85, action='Complete Ride', spaces={'ride_id': 1021, 'driver_id': 'Driver 32'}) at time 85
# Completing ride 1021 by driver Driver 32 at time 85
# Ride 1021 completed
# Processing event: Event(t=85, action='Complete Ride', spaces={'ride_id': 98, 'driver_id': 'Driver 22'}) at time 85
# Completing ride 98 by driver Driver 22 at time 85
# Ride 98 completed
# Processing event: Event(t=85, action='Driver Assigned', spaces={'ride_id': 1373, 'driver_id': 'Driver 46'}) at time 85
# Driver Driver 46 arrived at pickup for ride 1373 at time 85
# Ride 1373 in progress, will complete at time 108
# Processing event: Event(t=85, action='Driver Assigned', spaces={'ride_id': 359, 'driver_id': 'Driver 33'}) at time 85
# Driver Driver 33 arrived at pickup for ride 359 at time 85
# Ride 359 in progress, will complete at time 117
# State recorded
# Processing event: Event(t=86, action='Request Ride', spaces={'ride_id': 801}) at time 86
# Handling ride request event for ride 801 at time 86
# Travel time: 68, Cost: 68.0
# Driver Driver 8 assigned to ride 801 at time 154
# State recorded
# Processing event: Event(t=87, action='Complete Ride', spaces={'ride_id': 478, 'driver_id': 'Driver 4'}) at time 87
# Completing ride 478 by driver Driver 4 at time 87
# Ride 478 completed
# Processing event: Event(t=87, action='Driver Assigned', spaces={'ride_id': 1275, 'driver_id': 'Driver 50'}) at time 87
# Driver Driver 50 arrived at pickup for ride 1275 at time 87
# Ride 1275 in progress, will complete at time 116
# State recorded
# Processing event: Event(t=88, action='Request Ride', spaces={'ride_id': 1550}) at time 88
# Handling ride request event for ride 1550 at time 88
# Travel time: 45, Cost: 45.0
# Driver Driver 4 assigned to ride 1550 at time 133
# Processing event: Event(t=88, action='Request Ride', spaces={'ride_id': 151}) at time 88
# Handling ride request event for ride 151 at time 88
# Travel time: 35, Cost: 35.0
# Driver Driver 10 assigned to ride 151 at time 123
# State recorded
# Processing event: Event(t=89, action='Complete Ride', spaces={'ride_id': 994, 'driver_id': 'Driver 26'}) at time 89
# Completing ride 994 by driver Driver 26 at time 89
# Ride 994 completed
# Processing event: Event(t=89, action='Driver Assigned', spaces={'ride_id': 1133, 'driver_id': 'Driver 6'}) at time 89
# Driver Driver 6 arrived at pickup for ride 1133 at time 89
# Ride 1133 in progress, will complete at time 140
# Processing event: Event(t=89, action='Request Ride', spaces={'ride_id': 183}) at time 89
# Handling ride request event for ride 183 at time 89
# Travel time: 31, Cost: 31.0
# Driver Driver 11 assigned to ride 183 at time 120
# State recorded
# Processing event: Event(t=90, action='Complete Ride', spaces={'ride_id': 1192, 'driver_id': 'Driver 0'}) at time 90
# Completing ride 1192 by driver Driver 0 at time 90
# Ride 1192 completed
# State recorded
# Processing event: Event(t=91, action='Complete Ride', spaces={'ride_id': 1694, 'driver_id': 'Driver 37'}) at time 91
# Completing ride 1694 by driver Driver 37 at time 91
# Ride 1694 completed
# State recorded
# State recorded
# Processing event: Event(t=93, action='Complete Ride', spaces={'ride_id': 1315, 'driver_id': 'Driver 16'}) at time 93
# Completing ride 1315 by driver Driver 16 at time 93
# Ride 1315 completed
# Processing event: Event(t=93, action='Driver Assigned', spaces={'ride_id': 1432, 'driver_id': 'Driver 56'}) at time 93
# Driver Driver 56 arrived at pickup for ride 1432 at time 93
# Ride 1432 in progress, will complete at time 143
# State recorded
# Processing event: Event(t=94, action='Request Ride', spaces={'ride_id': 673}) at time 94
# Handling ride request event for ride 673 at time 94
# Travel time: 47, Cost: 47.0
# Driver Driver 0 assigned to ride 673 at time 141
# Processing event: Event(t=94, action='Request Ride', spaces={'ride_id': 536}) at time 94
# Handling ride request event for ride 536 at time 94
# Travel time: 14, Cost: 14.0
# Driver Driver 13 assigned to ride 536 at time 108
# State recorded
# Processing event: Event(t=95, action='Complete Ride', spaces={'ride_id': 53, 'driver_id': 'Driver 30'}) at time 95
# Completing ride 53 by driver Driver 30 at time 95
# Ride 53 completed
# Processing event: Event(t=95, action='Request Ride', spaces={'ride_id': 65}) at time 95
# Handling ride request event for ride 65 at time 95
# Travel time: 63, Cost: 63.0
# Driver Driver 15 assigned to ride 65 at time 158
# State recorded
# Processing event: Event(t=96, action='Complete Ride', spaces={'ride_id': 1399, 'driver_id': 'Driver 20'}) at time 96
# Completing ride 1399 by driver Driver 20 at time 96
# Ride 1399 completed
# Processing event: Event(t=96, action='Complete Ride', spaces={'ride_id': 1214, 'driver_id': 'Driver 40'}) at time 96
# Completing ride 1214 by driver Driver 40 at time 96
# Ride 1214 completed
# Processing event: Event(t=96, action='Driver Assigned', spaces={'ride_id': 1136, 'driver_id': 'Driver 5'}) at time 96
# Driver Driver 5 arrived at pickup for ride 1136 at time 96
# Ride 1136 in progress, will complete at time 122
# Processing event: Event(t=96, action='Request Ride', spaces={'ride_id': 986}) at time 96
# Handling ride request event for ride 986 at time 96
# Travel time: 30, Cost: 30.0
# Driver Driver 16 assigned to ride 986 at time 126
# State recorded
# Processing event: Event(t=97, action='Request Ride', spaces={'ride_id': 169}) at time 97
# Handling ride request event for ride 169 at time 97
# Travel time: 46, Cost: 46.0
# Driver Driver 18 assigned to ride 169 at time 143
# State recorded
# Processing event: Event(t=98, action='Complete Ride', spaces={'ride_id': 845, 'driver_id': 'Driver 24'}) at time 98
# Completing ride 845 by driver Driver 24 at time 98
# Ride 845 completed
# Processing event: Event(t=98, action='Driver Assigned', spaces={'ride_id': 1488, 'driver_id': 'Driver 51'}) at time 98
# Driver Driver 51 arrived at pickup for ride 1488 at time 98
# Ride 1488 in progress, will complete at time 145
# Processing event: Event(t=98, action='Driver Assigned', spaces={'ride_id': 1687, 'driver_id': 'Driver 2'}) at time 98
# Driver Driver 2 arrived at pickup for ride 1687 at time 98
# Ride 1687 in progress, will complete at time 119
# Processing event: Event(t=98, action='Request Ride', spaces={'ride_id': 1795}) at time 98
# Handling ride request event for ride 1795 at time 98
# Travel time: 34, Cost: 34.0
# Driver Driver 20 assigned to ride 1795 at time 132
# State recorded
# Processing event: Event(t=99, action='Request Ride', spaces={'ride_id': 566}) at time 99
# Handling ride request event for ride 566 at time 99
# Travel time: 63, Cost: 63.0
# Driver Driver 22 assigned to ride 566 at time 162
# Processing event: Event(t=99, action='Request Ride', spaces={'ride_id': 1128}) at time 99
# Handling ride request event for ride 1128 at time 99
# Travel time: 21, Cost: 21.0
# Driver Driver 24 assigned to ride 1128 at time 120
# State recorded
# Processing event: Event(t=100, action='Complete Ride', spaces={'ride_id': 518, 'driver_id': 'Driver 35'}) at time 100
# Completing ride 518 by driver Driver 35 at time 100
# Ride 518 completed
# Processing event: Event(t=100, action='Driver Assigned', spaces={'ride_id': 1044, 'driver_id': 'Driver 47'}) at time 100
# Driver Driver 47 arrived at pickup for ride 1044 at time 100
# Ride 1044 in progress, will complete at time 151
# Processing event: Event(t=100, action='Request Ride', spaces={'ride_id': 1605}) at time 100
# Handling ride request event for ride 1605 at time 100
# Travel time: 20, Cost: 20.0
# Driver Driver 26 assigned to ride 1605 at time 120
# State recorded
# Processing event: Event(t=101, action='Driver Assigned', spaces={'ride_id': 1853, 'driver_id': 'Driver 48'}) at time 101
# Driver Driver 48 arrived at pickup for ride 1853 at time 101
# Ride 1853 in progress, will complete at time 164
# Processing event: Event(t=101, action='Driver Assigned', spaces={'ride_id': 977, 'driver_id': 'Driver 14'}) at time 101
# Driver Driver 14 arrived at pickup for ride 977 at time 101
# Ride 977 in progress, will complete at time 146
# Processing event: Event(t=101, action='Request Ride', spaces={'ride_id': 89}) at time 101
# Handling ride request event for ride 89 at time 101
# Travel time: 11, Cost: 11.0
# Driver Driver 30 assigned to ride 89 at time 112
# State recorded
# Processing event: Event(t=102, action='Request Ride', spaces={'ride_id': 444}) at time 102
# Handling ride request event for ride 444 at time 102
# Travel time: 11, Cost: 11.0
# Driver Driver 32 assigned to ride 444 at time 113
# Processing event: Event(t=102, action='Request Ride', spaces={'ride_id': 290}) at time 102
# Handling ride request event for ride 290 at time 102
# Travel time: 40, Cost: 40.0
# Driver Driver 35 assigned to ride 290 at time 142
# Processing event: Event(t=102, action='Request Ride', spaces={'ride_id': 1074}) at time 102
# Handling ride request event for ride 1074 at time 102
# Travel time: 40, Cost: 40.0
# Driver Driver 37 assigned to ride 1074 at time 142
# State recorded
# Processing event: Event(t=103, action='Complete Ride', spaces={'ride_id': 643, 'driver_id': 'Driver 27'}) at time 103
# Completing ride 643 by driver Driver 27 at time 103
# Ride 643 completed
# State recorded
# Processing event: Event(t=104, action='Driver Assigned', spaces={'ride_id': 659, 'driver_id': 'Driver 53'}) at time 104
# Driver Driver 53 arrived at pickup for ride 659 at time 104
# Ride 659 in progress, will complete at time 164
# State recorded
# Processing event: Event(t=105, action='Request Ride', spaces={'ride_id': 1875}) at time 105
# Handling ride request event for ride 1875 at time 105
# Travel time: 37, Cost: 37.0
# Driver Driver 27 assigned to ride 1875 at time 142
# Processing event: Event(t=105, action='Request Ride', spaces={'ride_id': 1151}) at time 105
# Handling ride request event for ride 1151 at time 105
# Travel time: 36, Cost: 36.0
# Driver Driver 40 assigned to ride 1151 at time 141
# State recorded
# Processing event: Event(t=106, action='Complete Ride', spaces={'ride_id': 1772, 'driver_id': 'Driver 29'}) at time 106
# Completing ride 1772 by driver Driver 29 at time 106
# Ride 1772 completed
# Processing event: Event(t=106, action='Driver Assigned', spaces={'ride_id': 1440, 'driver_id': 'Driver 7'}) at time 106
# Driver Driver 7 arrived at pickup for ride 1440 at time 106
# Ride 1440 in progress, will complete at time 127
# Processing event: Event(t=106, action='Driver Assigned', spaces={'ride_id': 626, 'driver_id': 'Driver 52'}) at time 106
# Driver Driver 52 arrived at pickup for ride 626 at time 106
# Ride 626 in progress, will complete at time 140
# Processing event: Event(t=106, action='Request Ride', spaces={'ride_id': 941}) at time 106
# Handling ride request event for ride 941 at time 106
# Travel time: 31, Cost: 31.0
# Driver Driver 29 assigned to ride 941 at time 137
# State recorded
# Processing event: Event(t=107, action='Driver Assigned', spaces={'ride_id': 1227, 'driver_id': 'Driver 43'}) at time 107
# Driver Driver 43 arrived at pickup for ride 1227 at time 107
# Ride 1227 in progress, will complete at time 163
# Processing event: Event(t=107, action='Request Ride', spaces={'ride_id': 1578}) at time 107
# Handling ride request event for ride 1578 at time 107
# Travel time: 62, Cost: 62.0
# Driver Driver 61 assigned to ride 1578 at time 169
# Processing event: Event(t=107, action='Request Ride', spaces={'ride_id': 747}) at time 107
# Handling ride request event for ride 747 at time 107
# Travel time: 47, Cost: 47.0
# Driver Driver 62 assigned to ride 747 at time 154
# State recorded
# Processing event: Event(t=108, action='Complete Ride', spaces={'ride_id': 1373, 'driver_id': 'Driver 46'}) at time 108
# Completing ride 1373 by driver Driver 46 at time 108
# Ride 1373 completed
# Processing event: Event(t=108, action='Complete Ride', spaces={'ride_id': 367, 'driver_id': 'Driver 31'}) at time 108
# Completing ride 367 by driver Driver 31 at time 108
# Ride 367 completed
# Processing event: Event(t=108, action='Driver Assigned', spaces={'ride_id': 536, 'driver_id': 'Driver 13'}) at time 108
# Driver Driver 13 arrived at pickup for ride 536 at time 108
# Ride 536 in progress, will complete at time 127
# Processing event: Event(t=108, action='Request Ride', spaces={'ride_id': 410}) at time 108
# Handling ride request event for ride 410 at time 108
# Travel time: 34, Cost: 34.0
# Driver Driver 31 assigned to ride 410 at time 142
# State recorded
# Processing event: Event(t=109, action='Complete Ride', spaces={'ride_id': 508, 'driver_id': 'Driver 34'}) at time 109
# Completing ride 508 by driver Driver 34 at time 109
# Ride 508 completed
# Processing event: Event(t=109, action='Complete Ride', spaces={'ride_id': 160, 'driver_id': 'Driver 9'}) at time 109
# Completing ride 160 by driver Driver 9 at time 109
# Ride 160 completed
# Processing event: Event(t=109, action='Driver Assigned', spaces={'ride_id': 564, 'driver_id': 'Driver 58'}) at time 109
# Driver Driver 58 arrived at pickup for ride 564 at time 109
# Ride 564 in progress, will complete at time 151
# State recorded
# Processing event: Event(t=110, action='Driver Assigned', spaces={'ride_id': 739, 'driver_id': 'Driver 17'}) at time 110
# Driver Driver 17 arrived at pickup for ride 739 at time 110
# Ride 739 in progress, will complete at time 158
# State recorded
# Processing event: Event(t=111, action='Driver Assigned', spaces={'ride_id': 333, 'driver_id': 'Driver 54'}) at time 111
# Driver Driver 54 arrived at pickup for ride 333 at time 111
# Ride 333 in progress, will complete at time 156
# State recorded
# Processing event: Event(t=112, action='Complete Ride', spaces={'ride_id': 387, 'driver_id': 'Driver 12'}) at time 112
# Completing ride 387 by driver Driver 12 at time 112
# Ride 387 completed
# Processing event: Event(t=112, action='Driver Assigned', spaces={'ride_id': 256, 'driver_id': 'Driver 3'}) at time 112
# Driver Driver 3 arrived at pickup for ride 256 at time 112
# Ride 256 in progress, will complete at time 117
# Processing event: Event(t=112, action='Driver Assigned', spaces={'ride_id': 89, 'driver_id': 'Driver 30'}) at time 112
# Driver Driver 30 arrived at pickup for ride 89 at time 112
# Ride 89 in progress, will complete at time 153
# State recorded
# Processing event: Event(t=113, action='Driver Assigned', spaces={'ride_id': 667, 'driver_id': 'Driver 1'}) at time 113
# Driver Driver 1 arrived at pickup for ride 667 at time 113
# Ride 667 in progress, will complete at time 141
# Processing event: Event(t=113, action='Driver Assigned', spaces={'ride_id': 444, 'driver_id': 'Driver 32'}) at time 113
# Driver Driver 32 arrived at pickup for ride 444 at time 113
# Ride 444 in progress, will complete at time 150
# State recorded
# Processing event: Event(t=114, action='Request Ride', spaces={'ride_id': 905}) at time 114
# Handling ride request event for ride 905 at time 114
# Travel time: 60, Cost: 60.0
# Driver Driver 9 assigned to ride 905 at time 174
# Processing event: Event(t=114, action='Request Ride', spaces={'ride_id': 1089}) at time 114
# Handling ride request event for ride 1089 at time 114
# Travel time: 62, Cost: 62.0
# Driver Driver 12 assigned to ride 1089 at time 176
# State recorded
# Time: 1980, Completed Rides: 1879, Total Distance: 71782, Total Cost: 179455.0
# Time: 1981, Completed Rides: 1880, Total Distance: 71831, Total Cost: 179577.5
# Time: 1982, Completed Rides: 1881, Total Distance: 71888, Total Cost: 179720.0
# Time: 1983, Completed Rides: 1881, Total Distance: 71888, Total Cost: 179720.0
# Time: 1984, Completed Rides: 1881, Total Distance: 71888, Total Cost: 179720.0
# Time: 1985, Completed Rides: 1881, Total Distance: 71888, Total Cost: 179720.0
# Time: 1986, Completed Rides: 1882, Total Distance: 71936, Total Cost: 179840.0
# Time: 1987, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1988, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1989, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1990, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1991, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1992, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1993, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1994, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1995, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1996, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1997, Completed Rides: 1883, Total Distance: 71995, Total Cost: 179987.5
# Time: 1998, Completed Rides: 1884, Total Distance: 72066, Total Cost: 180165.0
# Verification successful: All ride requests were completed.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load state maps from the simulations
state_map_old_way = pd.read_csv('/Users/sayertindall/Documents/GitHub/block.science/rideshare/experiments/working/events/state_map_linear.csv')
state_map_DIPR_way = pd.read_csv('state_map_DIPR_way.csv')

def plot_metric_comparison(state_map1, state_map2, metric, title, ylabel):
    plt.figure(figsize=(10, 6))
    plt.plot(state_map1['time'], state_map1[metric], label='Old Way', marker='o')
    plt.plot(state_map2['time'], state_map2[metric], label='DIPR Way', marker='x')
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot and compare the metrics
plot_metric_comparison(state_map_old_way, state_map_DIPR_way, 'completed_rides', 'Completed Rides Over Time', 'Completed Rides')
plot_metric_comparison(state_map_old_way, state_map_DIPR_way, 'total_distance', 'Total Distance Covered Over Time', 'Total Distance (km)')
plot_metric_comparison(state_map_old_way, state_map_DIPR_way, 'total_cost', 'Total Cost Over Time', 'Total Cost (USD)')

# Determine the time steps taken to complete all rides
time_to_complete_old = state_map_old_way[state_map_old_way['completed_rides'] == state_map_old_way['completed_rides'].max()]['time'].min()
time_to_complete_DIPR = state_map_DIPR_way[state_map_DIPR_way['completed_rides'] == state_map_DIPR_way['completed_rides'].max()]['time'].min()

print(f"Time to complete all rides (Old Way): {time_to_complete_old} time steps")
print(f"Time to complete all rides (DIPR Way): {time_to_complete_DIPR} time steps")

# Determine which method is faster
if time_to_complete_old < time_to_complete_DIPR:
    print("The old way is faster.")
elif time_to_complete_old > time_to_complete_DIPR:
    print("The DIPR way is faster.")
else:
    print("Both methods are equally fast.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Load state maps from the simulations
#       5 state_map_old_way = pd.read_csv('/Users/sayertindall/Documents/GitHub/block.science/rideshare/experiments/working/events/state_map_linear.csv')
# ----> 6 state_map_DIPR_way = pd.read_csv('state_map_DIPR_way.csv')
#       8 def plot_metric_comparison(state_map1, state_map2, metric, title, ylabel):
#       9     plt.figure(figsize=(10, 6))
#
# File ~/Documents/GitHub/block.science/rideshare/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/GitHub/block.science/rideshare/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/GitHub/block.science/rideshare/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/GitHub/block.science/rideshare/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/GitHub/block.science/rideshare/venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'state_map_DIPR_way.csv'
